# %% [markdown]
# <a href="https://colab.research.google.com/github/KattaLasya/2303A51724_ADM/blob/main/Assignment3%5Bnetflix_titles%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
file_path = "/content/netflix_titles.csv"
df = pd.read_csv(file_path)

# %%
import matplotlib.pyplot as plt
plt.hist(data['release_year'].dropna(), bins=20, edgecolor='black', color='skyblue')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# plt.figure(figsize=(6, 4))
# data['release_year'].value_counts().plot(kind='bar', color='lightcoral')
# plt.title('Release Year')
# plt.xlabel('Year')
# plt.ylabel('Count')
# plt.xticks(rotation=0)
# plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='type', data=df, palette='pastel')
plt.title('Count of Movies vs. TV Shows')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-18-4c21cc233682>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='type', data=df, palette='pastel')

# %%
df['release_year'] = pd.to_numeric(df['release_year'], errors='coerce')
df.dropna(subset=['release_year'], inplace=True)

# %%
plt.figure(figsize=(8, 5))
df['release_year'].value_counts().sort_index().plot(kind='line', marker='o', color='b')
plt.title('Number of Titles Released Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(6, 6))
df['rating'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='coolwarm', startangle=90)
plt.title('Distribution of Content Ratings')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='type', y='release_year', data=df, palette='coolwarm')
plt.title('Boxplot of Release Year by Content Type')
plt.xlabel('Content Type')
plt.ylabel('Release Year')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-22-1e6b1c988e0a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='type', y='release_year', data=df, palette='coolwarm')
