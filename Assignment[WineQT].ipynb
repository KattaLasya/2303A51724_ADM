# %% [markdown]
# <a href="https://colab.research.google.com/github/KattaLasya/2303A51724_ADM/blob/main/Assignment%5BWineQT%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# importing or loading the dataset
dataset = pd.read_csv('/content/WineQT.csv')

# distributing the dataset into two components X and Y
X = dataset.iloc[:, 0:12].values
y = dataset.iloc[:, 12].values

# %%
# Splitting the X and Y into the
# Training set and Testing set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# performing preprocessing part
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Applying PCA function on training
# and testing set of X component
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

explained_variance = pca.explained_variance_ratio_

# %%
# Fitting Logistic Regression To the training set
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
# Predicting the test set result using
# predict function under LogisticRegression
y_pred = classifier.predict(X_test)

# %%
# Step 4: Visualize the reduced features (2D scatter plot)
plt.figure(figsize=(8, 6))
# Use y_test instead of y for the color, as X_pca is derived from X_test
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap='viridis', edgecolor='k', s=100)
plt.title('PCA of WineQt (2 Components)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Target Class')
plt.show()
# Optional: Explained Variance Ratio
print("Explained Variance Ratio of Each Component:")
print(pca.explained_variance_ratio_)
print(pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio of Each Component:
# [0.26484724 0.1874681 ]
# [0.26484724 0.1874681 ]
